# %% [markdown]
# <a href="https://colab.research.google.com/github/AlyxionCore40/New-Jupyter-Notebook/blob/main/my_first_notebook_alexia_y_chavez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"My First mardown cell in Jupyter"
# Out:
# 'My First mardown cell in Jupyter'

# %%
print("Hello, World!")
# Out:
# Hello, World!
