# %% [markdown]
# <a href="https://colab.research.google.com/github/AlyxionCore40/New-Jupyter-Notebook/blob/main/first_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # My First Jupyter Notebook
#
# My first markdown cell in Jupyter.
#
# This notebook was created as part of the **Colab and Other Tools Practice Run** lab session.

# %%
print("Hello, World!")
# Out:
# Hello, World!
